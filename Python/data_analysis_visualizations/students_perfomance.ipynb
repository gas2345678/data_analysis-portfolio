# %%
import pandas as pd 


import seaborn as sb

# %%
df =pd.read_csv(r"C:\Users\CR\Desktop\datasets_used\data_visualizations\Cleaned_Students_Performance.csv")

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education  lunch  \
# 0         0        group B           bachelor's degree      1
# 1         0        group C                some college      1
# 2         0        group B             master's degree      1
# 3         1        group A          associate's degree      0
# 4         1        group C                some college      1
# ..      ...            ...                         ...    ...
# 995       0        group E             master's degree      1
# 996       1        group C                 high school      0
# 997       0        group C                 high school      0
# 998       0        group D                some college      1
# 999       0        group D                some college      0
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# 0                          0          72             72             74
# 1                          1          69             90             88
# ...

# %%
df.shape
# Out:
# (1000, 10)

# %%
#we replace values of 1 and 0 by Male and Female
df.replace({ 1 : "Male",0 : "Female"})
# Out:
#      gender race_ethnicity parental_level_of_education   lunch  \
# 0    Female        group B           bachelor's degree    Male
# 1    Female        group C                some college    Male
# 2    Female        group B             master's degree    Male
# 3      Male        group A          associate's degree  Female
# 4      Male        group C                some college    Male
# ..      ...            ...                         ...     ...
# 995  Female        group E             master's degree    Male
# 996    Male        group C                 high school  Female
# 997  Female        group C                 high school  Female
# 998  Female        group D                some college    Male
# 999  Female        group D                some college  Female
#
#     test_preparation_course math_score  reading_score  writing_score  \
# 0                    Female         72             72             74
# ...

# %%
#¿Which gender had the highest total score?
genders_total_score = df.groupby("gender")["total_score"].sum()
genders_total_score
# Out:
# gender
# 0    108111
# 1     95201
# Name: total_score, dtype: int64

# %%
barplot = sb.barplot(data=df,x="gender",y="total_score",hue="gender")


barplot.set_ylabel("total score")
# Out:
# Text(0, 0.5, 'total score')

# %%
#We plot total score of students based on their race
plot_facet = sb.FacetGrid(data=df,col="race_ethnicity",hue="race_ethnicity")
