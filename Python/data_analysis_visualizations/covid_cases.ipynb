# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# %%
df_covid = pd.read_csv(r"C:\Users\CR\Desktop\datasets_used\data_visualizations\covid-19_cases.csv")

# %%
df_covid
# Out:
#       Date_reported Country_code      Country Continent WHO_region  New_cases  \
# 0        2020-01-05           AF  Afghanistan      Asia       EMRO        NaN
# 1        2020-01-12           AF  Afghanistan      Asia       EMRO        NaN
# 2        2020-01-19           AF  Afghanistan      Asia       EMRO        NaN
# 3        2020-01-26           AF  Afghanistan      Asia       EMRO        NaN
# 4        2020-02-02           AF  Afghanistan      Asia       EMRO        NaN
# ...             ...          ...          ...       ...        ...        ...
# 58555    2024-08-04           ZW     Zimbabwe    Africa       AFRO        1.0
# 58556    2024-08-11           ZW     Zimbabwe    Africa       AFRO        NaN
# 58557    2024-08-18           ZW     Zimbabwe    Africa       AFRO        NaN
# 58558    2024-08-25           ZW     Zimbabwe    Africa       AFRO        NaN
# 58559    2024-09-01           ZW     Zimbabwe    Africa       AFRO        NaN
#
# ...

# %%
#We drop null values
df_covid =df_covid.dropna()

# %%
df_covid.shape
# Out:
# (23970, 9)

# %%
df_covid["Country"].unique()
df_covid.loc[df_covid["Country"] == "Canada"]
# Out:
#      Date_reported Country_code Country      Continent WHO_region  New_cases  \
# 9038    2020-03-15           CA  Canada  North America       AMRO      125.0
# 9039    2020-03-22           CA  Canada  North America       AMRO      795.0
# 9040    2020-03-29           CA  Canada  North America       AMRO     3704.0
# 9041    2020-04-05           CA  Canada  North America       AMRO     7844.0
# 9042    2020-04-12           CA  Canada  North America       AMRO     9614.0
# ...            ...          ...     ...            ...        ...        ...
# 9262    2024-06-30           CA  Canada  North America       AMRO      605.0
# 9263    2024-07-07           CA  Canada  North America       AMRO      600.0
# 9264    2024-07-14           CA  Canada  North America       AMRO      519.0
# 9265    2024-07-21           CA  Canada  North America       AMRO      467.0
# 9266    2024-07-28           CA  Canada  North America       AMRO      327.0
#
# ...

# %%
#Total number of deaths by continent
deaths_by_continent = df_covid.groupby("Continent")["Cumulative_deaths"].sum()
deaths_by_continent
# Out:
# Continent
# Africa            20675509
# Asia             263536832
# Europe           219053477
# North America    178867653
# Oceania            2499711
# South America    161333182
# Uncategorized            8
# island                1083
# Name: Cumulative_deaths, dtype: int64

# %%
deaths_analysis = px.line(df_covid,x="Date_reported",y="Cumulative_deaths")
deaths_analysis
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File c:\Users\CR\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\CR\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...

# %%
bar_cases = px.bar(df_covid,x="Country",y="Cumulative_cases")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 bar_cases = px.bar(df_covid,x="Country",y="Cumulative_cases")
# ----> 2 bar_cases.show()
#
# File c:\Users\CR\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File c:\Users\CR\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
# ...
