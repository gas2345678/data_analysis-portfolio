# %%
import pandas as pd 
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # we load our dataset

# %%
df = pd.read_csv(r"C:\Users\CR\Downloads\Students_perfomance.csv")

# %%
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %% [markdown]
# # The average time of study of student

# %%
df["StudyTimeWeekly"].mean()
# Out:
# 9.771991919431738

# %%
print("in average,the best students in the world study " + str(rounded_hours)   + "hours per day")
# Out:
# in average,the best students in the world study 10.0hours per day

# %%
sb.relplot(data=df,x="StudyTimeWeekly",y="GPA",hue="Age",dashes=True)
mtp.xlabel("Study time")
mtp.ylabel("Grade point Average")
mtp.title("students perfomance")
# Out:
# Text(0.5, 1.0, 'students perfomance')

# %% [raw]
# there is no signal of influence in terms of age when talking about perfomance and grades

# %%
count_id = df["StudentID"].count()

# %% [markdown]
# sb.relplot(data=df,x="StudyTimeWeekly",y="GPA",hue="Gender")

# %% [raw]
# Besides,we have the same situation in terms of gender

# %% [markdown]
# # We rename the column "Gender"

# %%
df.replace({0: "Male", 1: "Female"})
# Out:
#       StudentID  Age  Gender Ethnicity ParentalEducation  StudyTimeWeekly  \
# 0          1001   17  Female      Male                 2        19.833723
# 1          1002   18    Male      Male            Female        15.408756
# 2          1003   15    Male         2                 3         4.210570
# 3          1004   17  Female      Male                 3        10.028829
# 4          1005   17  Female      Male                 2         4.672495
# ...         ...  ...     ...       ...               ...              ...
# 2387       3388   18  Female      Male                 3        10.680555
# 2388       3389   17    Male      Male            Female         7.583217
# 2389       3390   16  Female      Male                 2         6.805500
# 2390       3391   16  Female    Female              Male        12.416653
# 2391       3392   16  Female      Male                 2        17.819907
#
#      Absences Tutoring ParentalSupport Extracurricular  Sports   Music  \
# ...

# %% [markdown]
# # A general analysis of our data

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %% [markdown]
# # Weekly Study Time Separated by Gender

# %%
sb.barplot(data=df,x="Gender",y="StudyTimeWeekly",legend=False,hue="Gender")




plt.show()
