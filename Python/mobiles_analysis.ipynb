# %% [markdown]
# Here is a analysis of variables of mobiles and their influence on battery power

# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.DataFrame(df)

# %%
df = pd.read_csv(r"C:\Users\CR\Downloads\mobile_price.csv")

# %% [markdown]
# # Here we can see the dataframe of mobiles information

# %%
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %% [markdown]
#  # CREATING A GRAPHICAL REPRESENTATION OF TALK TIME ON BATTERY OF MOBILES

# %%
sb.lineplot(data=df,x="talk_time",y="battery_power")
plt.xlabel("talk time")
plt.ylabel("power of battery")
plt.title("the effects of talk time in mobile's battery")
# Out:
# Text(0.5, 1.0, "the effects of talk time in mobile's battery")

# %% [markdown]
# -As we can see, there is no relationship between talk time and power of battery

# %% [markdown]
# # Here is a regplot of ram influence on battery power

# %%
sb.regplot(data=df,x="ram",y="battery_power")
plt.title("ram influence on battery power")
# Out:
# Text(0.5, 1.0, 'ram influence on battery power')

# %% [markdown]
# We can see a small decrease in battery power related to ram consumed
