# %%
#We are gonna use a dataset which shows information about the league of lengeds world 2024.This dataset shows variables like champions perfomance, rates and in-game metrics.
import pandas as pd
import numpy as np 
import seaborn as sb

# %%
dt = pd.read_csv(r"C:\Users\CR\Desktop\datasets\champions.csv")
df = pd.DataFrame(dt)

# %%
# We drop null values and not Nan(not a number) values
df.dropna()
# Out:
#      Champion  Picks  Bans Presence  Wins  Losses Winrate   KDA Avg BT  \
# 0      Aurora      9    30     100%   7.0     2.0     78%   6.6    3.6
# 1        Yone     18    19      95%  13.0     5.0     72%   4.4    3.2
# 2        Rell     26     5      79%  15.0    11.0     58%   3.0    8.8
# 3         Jax     15    15      77%   6.0     9.0     40%   2.6      5
# 4     Skarner     13    17      77%   7.0     6.0     54%   3.9      4
# ..        ...    ...   ...      ...   ...     ...     ...   ...    ...
# 62      Urgot      1     0       3%   0.0     1.0      0%   2.3      -
# 63   Xin Zhao      1     0       3%   1.0     0.0    100%  11.0      -
# 67    Camille      1     0       3%   1.0     0.0    100%   6.5      -
# 68     Lillia      1     0       3%   0.0     1.0      0%   4.0      -
# 70       Hwei      1     0       3%   1.0     0.0    100%  19.0      -
#
#           GT   CSM    DPM    GPM  CSD@15  GD@15  XPD@15
# 0   32:52:00   7.9  678.0  402.0     0.6   76.0   -10.0
# ...

# %%
#We want to count the total number of bans of the event
bans_total = np.sum(df["Bans"])

# Champions with highest presence

lowest_presence = df["Presence"] > "80%"

df.loc[lowest_presence,"Champion"]
# Out:
# 1     Yone
# Name: Champion, dtype: object
